# %%
import sys
import subprocess

# 표준 파이썬 문법으로 터미널 명령어를 호출하는 방식입니다.
# 빨간 줄이 절대 뜨지 않습니다.
subprocess.check_call([sys.executable, "-m", "pip", "install", "biopython", "pandas", "openpyxl", "requests"])

print("✅ 설치 완료!")
