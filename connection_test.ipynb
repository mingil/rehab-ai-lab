# %%
import torch

print("🧪 AI 엔진 상태 점검")
print("-" * 20)

# 1. 파이토치 버전 확인
print(f"🔥 PyTorch 버전: {torch.__version__}")

# 2. GPU(CUDA) 사용 가능 여부
if torch.cuda.is_available():
    print("🚀 GPU 상태: 사용 가능 (고속 연산 모드)")
else:
    print("🐢 GPU 상태: 없음 (CPU 모드 동작)")
    
# 3. 간단한 텐서(행렬) 연산 테스트
x = torch.rand(5, 3)
print(f"\n[랜덤 행렬 생성 테스트]\n{x}")
# Out:
# 🧪 AI 엔진 상태 점검
# --------------------
# 🔥 PyTorch 버전: 2.9.1+cpu
# 🐢 GPU 상태: 없음 (CPU 모드 동작)
#
# [랜덤 행렬 생성 테스트]
# tensor([[0.5947, 0.6897, 0.7320],
#         [0.3789, 0.7737, 0.3548],
#         [0.2423, 0.0132, 0.5193],
#         [0.3446, 0.3026, 0.1788],
#         [0.5118, 0.9780, 0.2442]])
